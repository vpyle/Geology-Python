# %% [markdown]
# # First Attemp to create a fault visualization in 3D

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import re
from bs4 import BeautifulSoup
import tifffile as tiff
from geotiff import GeoTiff
from folium.plugins import MousePosition
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Creating the map

# %%
i_coords = [-33.47, -70.655]
site_map = folium.Map(location=i_coords, zoom_start=10, tiles='Stamen Terrain')

# %% [markdown]
# Mouse positioning

# %%
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position);

# %% [markdown]
# ## Importing DEM

# %%
filename = 'DEM_Stgo.tif'
tfile = tiff.imread(filename)
tiff.imshow(tfile) # display the map
# Out:
# (<Figure size 988.8x604.8 with 2 Axes>,
#  <AxesSubplot:>,
#  <matplotlib.image.AxesImage at 0x1bd6d50e580>)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Extracting Lat, Long and Elev from DEM

# %%
tiff_file = 'DEM_Stgo.tif'
DEM = GeoTiff(tiff_file)
zar_array = GeoTiff.read(DEM)
elev = np.array(zar_array) 
lon_array, lat_array = DEM.get_coord_arrays()

# %%
#Raster to xyz
lon = []; lat = []; z = []

for j in range(len(elev)):
    for i in range(len(elev)):
        lon.append(lon_array[j,i])
        lat.append(lat_array[j,i])
        z.append(elev[j,i])

# %% [markdown]
# ## Creating a Dataframe

# %%
if len(lon)==len(lat) & len(z)==len(lat):
    print ('Data OK!')
    print ('Creating dataframe')
    df = pd.DataFrame({'Latitud': lat, 'Longitud': lon, 'Elevation': z})
    df = df.astype('float')
    print ('Dataframe Created!')
else:
    print('Check Data')
# Out:
# Data OK!
# Creating dataframe
# Dataframe Created!

# %%
# From DEM.txt
df = pd.read_csv('DEM.txt')
lat = df.Latitud
lon = df.Longitud
z = df.Elevation

# %% [markdown]
# ### Add UTM datum

# %%
def coords_change(lon, lat, proj, zone):
    import pyproj
    import warnings
    warnings.filterwarnings("ignore", category=DeprecationWarning) 
    
    wgs84 = pyproj.Proj(proj='longlat', datum='WGS84')
    utm = pyproj.Proj(proj=proj, zone=zone, datum='WGS84')
    
    x, y = pyproj.transform(wgs84, utm, lon, lat)
        
    return x, y

# %%
change = coords_change(lon, lat, 'utm south', 19)
df['UTM_East'] = change[0]
df['UTM_North'] = change[1]

# %% [markdown]
# ### Set point type to DEM

# %%
df['type'] = str('DEM')

# %% [markdown]
# ### Save DF to txt

# %%
# Dataframe to txt file
df.to_csv('DEM.txt',sep=',',index=False)
print('txt file created!')
# Out:
# txt file created!

# %% [markdown]
# ## Ploting Topography

# %% [markdown]
# ### Extract and Drop some data to work

# %%
# work well untill 10^5*
def xyz(df, lon, lat, p, n):
    x = []; y = []; z = []
    index = np.linspace(0, len(df)-1, n, endpoint=True, dtype='int')
    for i in index:
        x.append(df[lon][i])
        y.append(df[lat][i])
        z.append(df[p][i])
    return x,y,z

# %%
lon_m, lat_m, z_m = xyz (df, 'UTM_East', 'UTM_North', 'Elevation', 10**5)

# %% [markdown]
# ### Scatter Plot

# %%
def scatt_plot_dem(x,y,z,e): # e correspond to elevation exageration
    # %matplotlib widget
    import matplotlib.pyplot as plt
    from mpl_toolkits.mplot3d import Axes3D
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(projection='3d')
    
    s = max((max(x)-min(x)),(max(y)-min(y)))
    mx = (max(x)+min(x))/2; my = (max(y)+min(y))/2
    
    ax.set_xlim(mx-s/2,mx+s/2)
    ax.set_ylim(my-s/2,my+s/2)
    ax.set_zlim(0-s/(2*e),0+s/(2*e))
    
    ax.set_xlabel('UTM East')
    ax.set_ylabel('UTM North')
    ax.set_zlabel('Elevation [m]')
    
    ax.scatter(x, y, z, c=z, cmap='gist_earth')

    plt.show()

# %%
scatt_plot_dem(lon_m,lat_m,z_m, 4)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Surface Plott

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')
fig_=ax.plot_surface(lon_array, lat_array, elev, cmap='gist_earth')
plt.colorbar(fig_)
plt.show()

# %% [markdown]
# ## Fault Trace

# %% [markdown]
# ### Import Fault from KML

# %%
with open('FSR.kml','r') as file:
    data = file.read()
    
soup = BeautifulSoup (data)

coords = []
for t in soup.find_all('coordinates'):
        coords.append(t.get_text("|", strip=True))
# Out:
# C:\Users\vicen\anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %%
lat_f = []; lon_f = []; trace = []

for i in range(len(coords)):
    a = coords[i].split(' ')
    for j in range(len(a)):
        b = a[j].split(',')
        lon_f.append(float(b[0]))
        lat_f.append(float(b[1]))
        trace.append(i)

# %%
df_fault = pd.DataFrame({'Latitud': lat_f, 'Longitud': lon_f, 'Elevation':np.zeros(len(lat_f)), 'type':'Fault', 
                         'trace':trace})

# %% [markdown]
# ### Print Fault on the map

# %%
for t in range(max(df_fault.trace)+1):
    fault_points = []
    df_trace = df_fault[df_fault.trace.eq(t)]
    
    for i in range(len(df_trace)):
        fault_points.append([df_trace.Latitud.iloc[i], df_trace.Longitud.iloc[i]])
        poly_fault = folium.PolyLine(locations=fault_points, color='black').add_to(site_map)

# %%
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### Set Fault Elevation

# %%
# Array of dem points
dem_points = np.c_[lat, lon, z]

# Array of fault points
fault_points = np.c_[lat_f, lon_f]

# %%
def distances_and_elevation (points, dem_points):
    min_dist = []
    elevations = []
    pnts = []
    dem_points_xy = np.array(dem_points)[:,:2]
    
    for p in points: 
        p = np.array(p)   
        d = np.sqrt(np.sum((dem_points_xy - p)**2, axis=1))
        min_dist.append(min(d))
        index = np.where(d == min(d))[0][0]
        elevations.append(dem_points[index][2])
        pnts.append(dem_points[index])
        
    return min_dist, elevations, pnts

# %%
md, elev_fault, points_selected = distances_and_elevation (fault_points, dem_points)

# %%
df_fault.Elevation = elev_fault

# %% [markdown]
# ### Add UTM Datum

# %%
fault_change = coords_change(lon_f, lat_f, 'utm south', 19)
df_fault['UTM_East'] = fault_change[0]
df_fault['UTM_North'] = fault_change[1]

# %% [markdown]
# ### Save to txt file

# %%
# Dataframe to txt file
df_fault.to_csv('fault_trace.txt',sep=',',index=False)
print('txt file created!')
# Out:
# txt file created!

# %% [markdown]
# ### Project Fault in Depth

# %% [markdown]
# #### Import dataframes from txt files

# %%
# DEM
df = pd.read_csv('DEM.txt')

# Fault trace
df_fault = pd.read_csv('fault_trace.txt')

# %%
def fault_proj(E, N, z, W, dip, dipdir, separation): # UTM coords
    import numpy as np
    alpha = np.deg2rad(dipdir); beta = np.deg2rad(dip)
    d_lon = separation*np.sin(alpha); d_lat = separation*np.cos(alpha)
    cicle = W*np.cos(beta)/separation
    x = []; y = []; p = []
    xf = []; yf = []; pf = []
    
    for i in range(int(cicle)):
        x.append((E-i*d_lon).values)
        y.append((N-i*d_lat).values)
        p.append((z-i*separation*np.tan(beta)).values)
        
        for j in range(len (x[i])):
            xf.append(x[i][j])
            yf.append(y[i][j])
            pf.append(p[i][j])
            
    return xf, yf, pf

# %%
xf, yf, pf = fault_proj (df_fault.UTM_East, df_fault.UTM_North, df_fault.Elevation, 20000, 34, 270, 100)

# %%
scatt_plot(xf, yf, pf, 1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def plotting(x1,y1,z1, x2,y2,z2, e): # e correspond to elevation exageration
    # %matplotlib widget
    import matplotlib.pyplot as plt
    from mpl_toolkits.mplot3d import Axes3D
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(projection='3d')
    
    s = max((max(x1)-min(x1)),(max(y1)-min(y1)))
    mx = (max(x1)+min(x1))/2; my = (max(y1)+min(y1))/2
    
    ax.set_xlim(mx-s/2,mx+s/2)
    ax.set_ylim(my-s/2,my+s/2)
    ax.set_zlim(0-s/(2*e),0+s/(2*e))
    
    ax.set_xlabel('UTM East')
    ax.set_ylabel('UTM North')
    
    fig1 = ax.scatter(x1, y1, z1, c=z1, cmap='gist_earth')
    
    fig2 = ax.scatter(x2, y2, z2)

    plt.colorbar(fig1,label='Elevation [m]')
    
    plt.show()

# %%
plotting(lon_m,lat_m,z_m, xf,yf,pf, 2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Seismic Events from CSN (Chile)

# %% [markdown]
# *Data obtained from CSN_extract.ipynb*

# %%
events = pd.read_csv('CSN_Events.csv')

# %% [markdown]
# ### Filter

# %%
def filt (p_min,p_max,param,data):
    data = data[data[param].le(p_max) & data[param].ge(p_min)]
    return data

# %%
events_filt1 = filt(df.Longitud.min(),df.Longitud.max(),'Longitud',events)
e_s = filt(df.Latitud.min(),df.Latitud.max(),'Latitud',events_filt1)

# %%
e_s.head()
# Out:
#                     Date  Latitud  Longitud  Depth  Magnitude
# 9    2022-11-08 08:51:16   -33.66    -70.77   92.0        5.3
# 16   2022-09-11 03:22:07   -33.21    -70.96   74.0        4.6
# 21   2022-08-29 13:17:20   -33.57    -70.80   91.0        4.5
# 113  2022-03-30 05:19:06   -33.49    -70.04   20.0        3.7
# 133  2022-03-03 04:56:41   -33.49    -70.47  105.0        4.5

# %% [markdown]
# ### Add UTM Datum

# %%
events_change = coords_change(e_s.Longitud, e_s.Latitud, 'utm south', 19)
e_s['UTM_East'] = events_change[0]
e_s['UTM_North'] = events_change[1]
# Out:
# C:\Users\vicen\AppData\Local\Temp\ipykernel_3636\1338089564.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   e_s['UTM_East'] = events_change[0]
# C:\Users\vicen\AppData\Local\Temp\ipykernel_3636\1338089564.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   e_s['UTM_North'] = events_change[1]

# %%
e_s.head()
# Out:
#                     Date  Latitud  Longitud  Depth  Magnitude       UTM_East  \
# 9    2022-11-08 08:51:16   -33.66    -70.77   92.0        5.3  335885.842885
# 16   2022-09-11 03:22:07   -33.21    -70.96   74.0        4.6  317325.577868
# 21   2022-08-29 13:17:20   -33.57    -70.80   91.0        4.5  332930.257345
# 113  2022-03-30 05:19:06   -33.49    -70.04   20.0        3.7  403386.012650
# 133  2022-03-03 04:56:41   -33.49    -70.47  105.0        4.5  363436.894757
#
#         UTM_North
# 9    6.274136e+06
# 16   6.323720e+06
# 21   6.284068e+06
# 113  6.293906e+06
# 133  6.293423e+06

# %% [markdown]
# ### Plot

# %%
def plot_all(x1,y1,z1, x2,y2,z2, x3,y3,z3,m3, e): # e correspond to elevation exageration
    # %matplotlib widget
    import matplotlib.pyplot as plt
    from mpl_toolkits.mplot3d import Axes3D
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(projection='3d')
    
    s = max((max(x1)-min(x1)),(max(y1)-min(y1)))
    mx = (max(x1)+min(x1))/2; my = (max(y1)+min(y1))/2
    
    ax.set_xlim(mx-s/2,mx+s/2)
    ax.set_ylim(my-s/2,my+s/2)
    ax.set_zlim(0-s/(2*e),0+s/(2*e))
    
    ax.set_xlabel('UTM East')
    ax.set_ylabel('UTM North')
    
    fig1 = ax.scatter(x1, y1, z1, c=z1, cmap='gist_earth')
    
    fig2 = ax.scatter(x2, y2, z2)

    fig3 = ax.scatter(x3, y3, z3, c=m3)
    
    plt.colorbar(fig1,label='Elevation [m]')
    plt.colorbar(fig3,label='Magnitude')
    
    plt.show()

# %%
plot_all(lon_m,lat_m,z_m, xf,yf,pf, e_s.UTM_East,e_s.UTM_North,e_s.Depth,e_s.Magnitude, 4)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
